# %% [markdown]
# # Pasta Shape Recognizer
# The goal of this project is to classify 20 different types of pasta shapes. The types are following:
#
# 1. Spaghetti
# 2. Fettuccine
# 3. Penne
# 4. Rigatoni
# 5. Fusilli
# 6. Farfalle
# 7. Linguine
# 8. Tagliatelle
# 9. Lasagna
# 10. Ravioli
# 11. Tortellini
# 12. Orecchiette
# 13. Conchiglie
# 14. Rotini
# 15. Bucatini
# 16. Cannelloni
# 17. Macaroni
# 18. Orzo
# 19. Cavatappi
# 20. Gemelli

# %% [markdown]
# ## Setting Up for Inference

# %%
from fastai.vision.all import *

# %%
version = 2
img_path = "../deployment"
model_path = "../models/pasta_shape_recognizer"

# %%
model = load_learner(f"{model_path}_v{version}.pkl")

# %% [markdown]
# ## Inference 1
#
# **Target:** sphagetti

# %%
img = Image.open(f'{img_path}/unknown00.png')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
model.predict(f'{img_path}/unknown00.png')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('spaghetti',
#  tensor(17),
#  tensor([7.4481e-04, 3.0122e-05, 6.6900e-06, 2.1363e-05, 7.0338e-06, 7.7152e-04,
#          7.2145e-06, 3.4032e-07, 3.0654e-05, 2.3691e-03, 1.1775e-05, 1.0839e-05,
#          2.7005e-05, 9.8558e-07, 1.1222e-05, 1.1215e-04, 6.0131e-06, 9.9559e-01,
#          2.2351e-04, 1.9456e-05]))

# %% [markdown]
# ## Inference 2
#
# **Target:** fettuccine

# %%
img = Image.open(f'{img_path}/unknown01.png')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
model.predict(f'{img_path}/unknown01.png')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('fettuccine',
#  tensor(5),
#  tensor([1.2856e-03, 1.3526e-06, 1.5411e-05, 1.6013e-04, 3.4877e-04, 4.0389e-01,
#          2.4704e-05, 1.3396e-05, 9.7262e-07, 3.3555e-01, 2.0038e-06, 4.2459e-04,
#          3.4952e-04, 9.0958e-05, 2.4218e-05, 2.2691e-06, 6.1185e-05, 4.0678e-03,
#          2.5353e-01, 1.5778e-04]))

# %% [markdown]
# ## Inference 3
# **Target:** fusilli

# %%
img = Image.open(f'{img_path}/unknown02.png')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict(f'{img_path}/unknown02.png')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('fusilli',
#  tensor(6),
#  tensor([9.7174e-05, 2.9155e-05, 4.9339e-05, 2.6243e-04, 2.1123e-04, 1.4221e-04,
#          8.9048e-01, 8.6132e-05, 1.6828e-05, 1.0639e-04, 1.9662e-05, 1.8744e-05,
#          7.3194e-05, 3.7425e-05, 8.1646e-04, 3.3558e-04, 1.0711e-01, 5.2671e-05,
#          3.9219e-05, 1.5682e-05]))

# %% [markdown]
# ## Inference 4
# **Target:** penne

# %%
img = Image.open(f'{img_path}/unknown03.png')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x107>

# %%
model.predict(f'{img_path}/unknown03.png')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('penne',
#  tensor(13),
#  tensor([1.1336e-04, 5.0446e-07, 4.9844e-08, 2.0851e-03, 9.5460e-07, 6.0439e-06,
#          2.8417e-07, 1.5284e-04, 2.0782e-06, 4.8451e-06, 7.3616e-07, 2.6908e-05,
#          2.1076e-06, 9.9755e-01, 1.2090e-07, 4.1925e-05, 6.0882e-08, 3.1298e-07,
#          7.5527e-06, 6.9304e-06]))

# %% [markdown]
# ## Inference 5
# **Target:** rigatoni

# %%
img = Image.open(f'{img_path}/unknown04.png')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=96x128>

# %%
model.predict(f'{img_path}/unknown04.png')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('rigatoni',
#  tensor(15),
#  tensor([9.4274e-06, 6.5781e-05, 3.3360e-06, 4.6255e-06, 4.5337e-06, 2.9222e-07,
#          9.3497e-06, 1.9200e-06, 4.5694e-06, 1.9700e-07, 1.0097e-06, 4.5745e-06,
#          7.9689e-07, 1.8758e-04, 2.8284e-05, 9.9966e-01, 3.2069e-06, 6.9270e-06,
#          5.6571e-07, 1.1876e-07]))

# %% [markdown]
# ## Inference 6
# **Target:** macaroni

# %%
img = Image.open(f'{img_path}/unknown05.png')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=102x128>

# %%
model.predict(f'{img_path}/unknown05.png')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('macaroni',
#  tensor(10),
#  tensor([3.0078e-03, 7.3822e-05, 9.9801e-02, 1.8855e-04, 6.9223e-06, 3.8994e-06,
#          6.8099e-05, 1.2404e-05, 1.6199e-05, 1.8323e-05, 8.9559e-01, 1.9595e-04,
#          6.3937e-06, 6.5503e-06, 4.8334e-06, 6.6589e-05, 3.7114e-05, 5.7980e-04,
#          8.3889e-06, 3.1062e-04]))

# %% [markdown]
# ## Inference 7
# **Target:** cannelloni

# %%
img = Image.open(f'{img_path}/unknown06.png')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/unknown06.png')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('cannelloni',
#  tensor(1),
#  tensor([1.9573e-04, 7.7468e-01, 2.2036e-02, 1.2616e-01, 8.9328e-05, 4.5647e-04,
#          6.9360e-03, 5.5098e-04, 6.1226e-03, 9.1129e-04, 5.0527e-03, 2.8755e-02,
#          8.2497e-04, 3.6950e-04, 7.2902e-03, 1.0297e-02, 1.9341e-03, 6.9443e-04,
#          3.1285e-04, 6.3287e-03]))

# %% [markdown]
# ## Inference 8
# **Target:** conchiglie

# %%
img = Image.open(f'{img_path}/unknown07.png')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x72>

# %%
model.predict(f'{img_path}/unknown07.png')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('conchiglie',
#  tensor(3),
#  tensor([5.3257e-06, 6.7404e-07, 1.0197e-04, 9.6598e-01, 8.3454e-06, 1.4800e-06,
#          3.7976e-05, 2.3149e-05, 3.1293e-06, 4.4211e-06, 1.5934e-05, 3.3642e-02,
#          5.5783e-05, 4.0485e-05, 4.3614e-06, 7.3934e-06, 1.6650e-05, 5.8965e-06,
#          4.8403e-06, 4.0610e-05]))

# %% [markdown]
# ## Inference 9
# **Target:** farfalle

# %%
img = Image.open(f'{img_path}/unknown08.png')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=85x128>

# %%
model.predict(f'{img_path}/unknown08.png')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('farfalle',
#  tensor(4),
#  tensor([2.0698e-04, 2.7262e-05, 2.0139e-03, 2.4216e-03, 7.6755e-01, 7.1767e-04,
#          4.0380e-04, 2.2278e-04, 4.0770e-05, 9.9994e-04, 1.2727e-04, 1.4172e-01,
#          4.3327e-04, 1.9165e-04, 2.0564e-03, 7.9765e-05, 2.3017e-04, 6.8379e-04,
#          2.8433e-03, 7.7023e-02]))

# %% [markdown]
# ## Inference 10
# **Target:** lasagna

# %%
img = Image.open(f'{img_path}/unknown09.png')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x77>

# %%
model.predict(f'{img_path}/unknown09.png')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('lasagna',
#  tensor(8),
#  tensor([2.8838e-03, 7.9997e-03, 5.4915e-05, 8.5887e-05, 1.1779e-04, 4.4996e-04,
#          1.6774e-05, 7.6895e-05, 9.7969e-01, 4.1502e-03, 2.4168e-04, 1.2475e-04,
#          1.7782e-05, 5.9816e-05, 3.8530e-04, 1.1823e-04, 2.0464e-05, 8.1483e-04,
#          2.2338e-03, 4.5609e-04]))

# %% [markdown]
# ## Inference 11
# **Target:** orecchiette

# %%
img = Image.open(f'{img_path}/unknown10.png')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x116>

# %%
model.predict(f'{img_path}/unknown10.png')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('orecchiette',
#  tensor(11),
#  tensor([2.6131e-05, 5.6796e-04, 1.9055e-05, 5.7255e-04, 3.6502e-06, 3.3888e-06,
#          1.7772e-07, 6.9760e-06, 1.0014e-05, 1.1866e-05, 2.9712e-06, 9.9848e-01,
#          1.1730e-07, 1.6566e-06, 1.7614e-04, 1.1120e-06, 4.5880e-08, 3.2166e-06,
#          1.0428e-05, 9.9675e-05]))

# %% [markdown]
# ## Inference 12
# **Target:** orzo

# %%
img = Image.open(f'{img_path}/unknown11.png')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=103x128>

# %%
model.predict(f'{img_path}/unknown11.png')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('orzo',
#  tensor(12),
#  tensor([5.3312e-05, 5.0359e-04, 2.3634e-03, 3.9223e-03, 6.1071e-04, 1.2172e-05,
#          3.7708e-04, 1.8965e-02, 2.8021e-04, 1.9719e-04, 6.5469e-05, 4.3335e-03,
#          9.5625e-01, 1.8652e-03, 1.7242e-03, 1.2172e-04, 6.0649e-04, 2.3438e-04,
#          1.5742e-04, 7.3577e-03]))

# %% [markdown]
# ## Inference 13
# **Target:** ravioli

# %%
img = Image.open(f'{img_path}/unknown12.png')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=85x128>

# %%
model.predict(f'{img_path}/unknown12.png')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('ravioli',
#  tensor(14),
#  tensor([8.9027e-04, 2.6746e-04, 2.3366e-05, 5.7244e-06, 1.1620e-03, 3.9625e-04,
#          2.2891e-04, 7.0865e-04, 4.1710e-05, 4.0137e-04, 4.7998e-07, 1.8355e-03,
#          1.7490e-04, 4.2722e-05, 9.8878e-01, 2.9230e-05, 2.4456e-05, 5.3281e-05,
#          6.8157e-04, 4.2540e-03]))

# %% [markdown]
# ## Inference 14
# **Target:** tortellini

# %%
img = Image.open(f'{img_path}/unknown13.png')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=85x128>

# %%
model.predict(f'{img_path}/unknown13.png')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('tortellini',
#  tensor(19),
#  tensor([1.0651e-02, 3.1702e-04, 1.1029e-01, 2.4822e-04, 3.0412e-05, 6.3660e-05,
#          5.7574e-05, 6.9801e-05, 9.8250e-06, 1.1093e-02, 2.0877e-03, 2.1266e-01,
#          8.7292e-05, 1.0574e-04, 2.2246e-04, 2.3026e-04, 2.0392e-05, 1.0634e-02,
#          1.6065e-04, 6.4096e-01]))
